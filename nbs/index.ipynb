# %%
#| hide

# %% [markdown]
# # ros2_cam_nbdev
#
# > Development and easy guide on ROS2 camera nodes

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install ros2_cam_nbdev in Development mode

# %% [markdown]
# ```sh
# # make sure ros2_cam_nbdev package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to ros2_cam_nbdev
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/Ramon-PR/ros2_cam_nbdev.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c Ramon-PR ros2_cam_nbdev
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install ros2_cam_nbdev
# ```
#
#
# [repo]: https://github.com/Ramon-PR/ros2_cam_nbdev
# [docs]: https://Ramon-PR.github.io/ros2_cam_nbdev/
# [pypi]: https://pypi.org/project/ros2_cam_nbdev/
# [conda]: https://anaconda.org/Ramon-PR/ros2_cam_nbdev

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/Ramon-PR/ros2_cam_nbdev
# [docs]: https://Ramon-PR.github.io/ros2_cam_nbdev/
# [pypi]: https://pypi.org/project/ros2_cam_nbdev/
# [conda]: https://anaconda.org/Ramon-PR/ros2_cam_nbdev

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
